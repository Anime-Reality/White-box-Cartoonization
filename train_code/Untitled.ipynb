# %%
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %cd train_code
# Out:
# [Errno 2] No such file or directory: 'train_code'
# /home/thanit456/university/computervision/White-box-Cartoonization/train_code

# %%
# %cd dataset
# Out:
# /home/thanit456/university/computervision/White-box-Cartoonization/train_code/dataset

# %%
fnames = os.listdir(new_face_root)

# %%
old_root = 'cartoon_face_old'
new_face_root = 'cartoon_face'
new_scene_root = 'cartoon_scenery'

dim = (256, 256)

# %%
i == 0
for root in [new_face_root, new_scene_root]:
    print(root)
    for fname in os.listdir(root):
        try:
            i += 1
            img = cv2.imread(root+'/'+fname, cv2.IMREAD_UNCHANGED)
            resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
            cv2.imwrite(root+'/'+fname, resized)
        except:
            print(root+'/'+fname)
print('finish')
print(i)
# Out:
# cartoon_face
# cartoon_scenery
# finish
# 30312

# %%
i = 0
for root in [new_face_root, new_scene_root]:
    print(root)
    for fname in os.listdir(root):
        img = cv2.imread(root+'/'+fname, cv2.IMREAD_UNCHANGED)
        i+=1
        if (img.shape != (256, 256, 3)):
            print(root+'/'+fname)
print('finish')
print(i)
# Out:
# cartoon_face
# cartoon_scenery
# finish
# 14233

# %%
resized = cv2.resize(a, dim, interpolation = cv2.INTER_AREA)
plt.imshow(resized)
print(resized.shape)
# Out:
# (256, 256, 3)
